# %%
#A1

import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import IPython.display as ipd

y, sr = librosa.load('Devendra.wav')
derivative = np.diff(y)
derivative /= np.max(np.abs(derivative_1))

print("First Derivative Signal:")

plt.figure(figsize=(10, 5))
librosa.display.waveshow(derivative, sr=sr,color='red')
plt.title('First Derivative')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid(True)
plt.tight_layout()
plt.show()

ipd.Audio(derivative, rate=sr)
# Out:
# First Derivative Signal:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#ORIGINAL 
plt.figure(figsize=(10, 5))
librosa.display.waveshow(y, sr=sr,color='blue')
plt.title('Original')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid(True)
plt.tight_layout()
plt.show()

ipd.Audio(y, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#A2

zero_crossing = np.where(np.diff(np.sign(derivative_1)))[0]
diff = np.diff(zero_crossing)
threshold = 1000
speech_regions = diff[diff > threshold]
silence_regions = diff[diff <= threshold]

avg_length_speech = np.mean(speech_regions)
avg_length_silence = np.mean(silence_regions)

print("Average length b/w consecutive zero crossings in speech regions:", avg_length_speech)
print("Average length b/w consecutive zero crossings in silence regions:", avg_length_silence)

plt.figure(figsize=(10, 5))
plt.plot(diff, label='All regions',color = 'blue')
plt.plot(np.arange(len(speech_regions)), speech_regions, 'ro', label='Speech regions',color = 'yellow')
plt.plot(np.arange(len(speech_regions), len(speech_regions) + len(silence_regions)), silence_regions, 'bo', label='Silence regions',color = 'red')
plt.title('Pattern of Zero Crossings')
plt.xlabel('Zero Crossing Difference')
plt.ylabel('Difference between Consecutive Zero Crossings')
plt.legend()
plt.show()

print("Pattern of Zero Crossings:")
print("All regions:", diff)
print("Speech regions:", speech_regions)
print("Silence regions:", silence_regions)
# Out:
# Average length b/w consecutive zero crossings in speech regions: nan
# Average length b/w consecutive zero crossings in silence regions: 3.181460428508964
# C:\Users\deven\AppData\Local\Temp\ipykernel_17936\2223697123.py:17: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(np.arange(len(speech_regions)), speech_regions, 'ro', label='Speech regions',color = 'yellow')
# C:\Users\deven\AppData\Local\Temp\ipykernel_17936\2223697123.py:18: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "bo" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(np.arange(len(speech_regions), len(speech_regions) + len(silence_regions)), silence_regions, 'bo', label='Silence regions',color = 'red')
# Pattern of Zero Crossings:
# All regions: [1 1 1 ... 1 4 1]
# Speech regions: []
# Silence regions: [1 1 1 ... 1 4 1]

# %%
#A3

word_files_mine = ['Microsoft.wav', 'Amazon.wav', 'Apple.wav', 'Tesla.wav', 'Paytm.wav']
word_files_team_mate = ['Microsoft_1.wav', 'Amazon_1.wav', 'Apple_1.wav', 'Tesla_1.wav', 'Paytm_1.wav']
words = ['Microsoft', 'Amazon', 'Apple', 'Tesla', 'Paytm']
word_lengths_mine = []
word_lengths_teammate = []

for word_file in word_files_mine:
    signal, sr = librosa.load(word_file, sr=None)
    length_seconds = len(signal) / sr
    word_lengths_mine.append(length_seconds)

for word_file in word_files_team_mate:
    signal, sr = librosa.load(word_file, sr=None)
    length_seconds = len(signal) / sr
    word_lengths_teammate.append(length_seconds)

print("Lengths of the spoken words MINE:", word_lengths_mine)
print("Lengths of the spoken words TeamMate:", word_lengths_teammate)

bar_width = 0.35
index = np.arange(len(words))
plt.figure(figsize=(12, 6))
plt.bar(index - bar_width/2, word_lengths_mine, bar_width, label='My Words', color='green')
plt.bar(index + bar_width/2, word_lengths_teammate, bar_width, label="Teammate's Words", color='red')
plt.xlabel('Words')
plt.ylabel('Length (seconds)')
plt.title('Comparison of Spoken Words Length')
plt.xticks(index, words)
plt.legend()

plt.show()
# Out:
# Lengths of the spoken words MINE: [3.18, 2.76, 2.7, 2.58, 2.28]
# Lengths of the spoken words TeamMate: [2.88, 3.84, 3.72, 3.96, 4.8]

# %%
#A4

statement, sr1 = librosa.load('Statement.wav')
question, sr2 = librosa.load('Question.wav')

plt.figure(figsize=(10, 5))
librosa.display.waveshow(statement, sr=sr1,color='blue')
plt.title('Statement')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid(True)
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 5))
librosa.display.waveshow(statement, sr=sr2,color='blue')
plt.title('Question')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid(True)
plt.tight_layout()
plt.show()
